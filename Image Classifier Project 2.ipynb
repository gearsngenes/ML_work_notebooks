# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import torch
from torchvision import datasets, transforms, models
from torchvision.transforms import functional as TF
from torch import nn
from torch import optim
import torch.nn.functional as F
from PIL import Image
import matplotlib as plt

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.Resize(255),
                                transforms.CenterCrop(224),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize((0.485, 0.485, 0.485), (0.229, 0.224, 0.225))])
valid_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
testing_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
valid_data = datasets.ImageFolder(train_dir, transform=valid_transforms)
test_data = datasets.ImageFolder(train_dir, transform=testing_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=24, shuffle=True)
valid_dataloader = torch.utils.data.DataLoader(valid_data, batch_size=24, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=24, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
#Get the pre-trained neural network
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = models.vgg11(pretrained=True)



# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False

model.classifier = nn.Sequential(nn.Linear(25088, 2048),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(2048, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(512, 102),
                                 nn.LogSoftmax(dim=1))
criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)

model.to(device);

print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11-bbd30ac9.pth" to /root/.torch/models/vgg11-bbd30ac9.pth
# 100%|██████████| 531456000/531456000 [00:05<00:00, 91164561.31it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=2048, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#     (3): Linear(in_features=2048, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2)
#     (6): Linear(in_features=512, out_features=102, bias=True)
#     (7): LogSoftmax()
#   )
# )

# %%
epochs = 2
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
    for inputs, labels in train_dataloader:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        print("Epoch: ", epoch, "     Loss: ", loss)
        
        '''if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in test_dataloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    test_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(test_dataloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(test_dataloader):.3f}")
            running_loss = 0
            model.train()'''
# Out:
# Epoch:  0      Loss:  tensor(4.6126, device='cuda:0')
# Epoch:  0      Loss:  tensor(18.7393, device='cuda:0')
# Epoch:  0      Loss:  tensor(20.7393, device='cuda:0')
# Epoch:  0      Loss:  tensor(15.7285, device='cuda:0')
# Epoch:  0      Loss:  tensor(11.6832, device='cuda:0')
# Epoch:  0      Loss:  tensor(7.8565, device='cuda:0')
# Epoch:  0      Loss:  tensor(5.1282, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.7970, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.8853, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.6112, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.6101, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.6518, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.4425, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.6408, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.7835, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.6079, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.4715, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.3284, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.0317, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.9416, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.9916, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.4975, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.8777, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.5706, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.3187, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.1175, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.9154, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.9330, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.9782, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.0396, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.5751, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.5909, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.6837, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.2275, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.3234, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.7580, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3973, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.1562, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.2178, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3320, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.2982, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1661, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.6279, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.4555, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.3855, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.5758, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1836, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.0493, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.8037, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9303, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3029, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8610, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3936, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9819, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8599, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5880, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.8709, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2625, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.0311, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1651, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.4345, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7098, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.0891, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3948, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.7391, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9959, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3692, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1950, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.7660, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.7190, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2583, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.5841, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2017, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.7367, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.0812, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7055, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1390, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3727, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6263, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1303, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1267, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3432, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.8966, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7403, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6191, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6845, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3983, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7694, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7243, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8983, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.4354, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9273, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3287, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6823, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5538, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7917, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2527, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7910, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3434, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8340, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8741, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7812, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3306, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.8108, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2931, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5568, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6139, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1843, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1454, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2534, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.0457, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7133, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0298, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.4122, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3080, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3721, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.2004, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3014, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1365, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0565, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.6754, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9200, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9500, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1812, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4874, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4671, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5182, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8515, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.8864, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.4005, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.8573, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6340, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3316, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6998, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8455, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.6716, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.0986, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5040, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0446, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3148, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.6252, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9815, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1366, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6638, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2713, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7381, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6864, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.2004, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3042, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2235, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5472, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0251, device='cuda:0')
# Epoch:  0      Loss:  tensor(4.0353, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1452, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4186, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2136, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9587, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8716, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9123, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5130, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.7914, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2706, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5605, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7477, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0164, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8238, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3500, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1566, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2939, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.4833, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.2200, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.2195, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7405, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.0816, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5294, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5154, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2811, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7259, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1045, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7931, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.0915, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.5405, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.2834, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7007, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.7895, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2601, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.4461, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8279, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.6599, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.5710, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5571, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.4178, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5446, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0190, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3901, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.6911, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1708, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.7980, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5280, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4942, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3027, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2334, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5120, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.6047, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.9765, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2942, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0798, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3893, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.5373, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7233, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0405, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.3305, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.9267, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8269, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0300, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0620, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7071, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5601, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2130, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.2743, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3992, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3792, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0534, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7160, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1131, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1154, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4754, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.7927, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4137, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2565, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4533, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7157, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5411, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4363, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8373, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.8139, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5633, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2082, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2224, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.6631, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.9857, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.8063, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1245, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.9374, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.5841, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9680, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9020, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2019, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1652, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2454, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6729, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.2605, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4424, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1073, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.3414, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.1820, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.7556, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.8763, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4766, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.6319, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.4606, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.9027, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.7671, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.2647, device='cuda:0')
# Epoch:  0      Loss:  tensor(5.2293, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.2809, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.8033, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.0721, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1959, device='cuda:0')
# Epoch:  0      Loss:  tensor(1.7542, device='cuda:0')
# Epoch:  0      Loss:  tensor(3.4069, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.1437, device='cuda:0')
# Epoch:  0      Loss:  tensor(2.5788, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8774, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7884, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4576, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4282, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4780, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5780, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2248, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5718, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6681, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.6551, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6118, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4209, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0303, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3764, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9834, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7377, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4320, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8120, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.2809, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8662, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8992, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.9706, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3744, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8234, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4735, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4570, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7613, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3796, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4980, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6861, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7706, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8903, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8025, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6314, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.3518, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7566, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4520, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8317, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4148, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1554, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.9564, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7368, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0221, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4056, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3652, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5632, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9375, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3215, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.6971, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1100, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.2659, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1173, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1444, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2890, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7607, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9505, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2415, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5687, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3076, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.5366, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7150, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7904, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9790, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5328, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3411, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2521, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7415, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8248, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5915, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3369, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4932, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1326, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5221, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7930, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6114, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5777, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1110, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7917, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5739, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3736, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8460, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7442, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8424, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6725, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5655, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6721, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0848, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8709, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9801, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4687, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5617, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7582, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4332, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.3378, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5948, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6831, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5737, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8718, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8290, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3832, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1838, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.2112, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.0452, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.6979, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.3054, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4575, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0605, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0815, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5493, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0306, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4688, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1751, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.0875, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.3709, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6747, device='cuda:0')
# Epoch:  1      Loss:  tensor(0.7604, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6818, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8262, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3251, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9711, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5920, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5051, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7966, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9658, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2679, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9520, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9131, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.0796, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0101, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.6374, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1197, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7324, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8309, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5649, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.2682, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.1361, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8348, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6170, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7537, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.2757, device='cuda:0')
# Epoch:  1      Loss:  tensor(0.9596, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1503, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7947, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8926, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2402, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3777, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1930, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.2048, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.2369, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.6011, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4594, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7051, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3433, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9510, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5442, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1345, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3910, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.9284, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6960, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5352, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8040, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3322, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1448, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9952, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3220, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4989, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.9592, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3766, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7897, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2003, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6450, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8245, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.6305, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1243, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1851, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7295, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7751, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8343, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4378, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3556, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3996, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8184, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4121, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4837, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7668, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0604, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1690, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.1843, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.4286, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2333, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8867, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3490, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3544, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6578, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5211, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1988, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.9100, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4866, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8084, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4511, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6018, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2714, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5168, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0887, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9761, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.7301, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4329, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9299, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.8258, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7065, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5251, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6187, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9656, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0045, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.6127, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9264, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.9173, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7387, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7029, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.4581, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4553, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4041, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9302, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8592, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0668, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8821, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0213, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.9950, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2780, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8161, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.1033, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.6095, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1642, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5871, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.0407, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5718, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3785, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1875, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4225, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1423, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8957, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.2568, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6126, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3580, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.2451, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8333, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1672, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3037, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8793, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.4219, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7999, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.7615, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.8924, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.3811, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6141, device='cuda:0')
# Epoch:  1      Loss:  tensor(3.4878, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1758, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0409, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0698, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.5009, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.7845, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6770, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.1293, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.1951, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0637, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.0192, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.2875, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.5842, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.8799, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.9690, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.3098, device='cuda:0')
# Epoch:  1      Loss:  tensor(2.2224, device='cuda:0')
# Epoch:  1      Loss:  tensor(1.6895, device='cuda:0')

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_losses, test_losses = [], []
epochs = 2
steps = 0

test_loss = 0
accuracy = 0
# Turn off gradients for validation, saves memory and computations
for e in range(epochs):
    running_loss = 0
    print("Training...")
    for images, labels in train_dataloader:
        steps += 1
        # Move input and label tensors to the default device
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(images)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    else:
        print("Testing...")
        ## TODO: Implement the validation pass and print out the validation accuracy
        with torch.no_grad():
        model.eval()
        for images, labels in valid_dataloader:
            images, labels = images.to(device), labels.to(device)
            log_ps = model.forward(images)
            test_loss += criterion(log_ps, labels)
            ps = torch.exp(log_ps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor))
        model.train()
        test_losses.append(test_loss/len(valid_dataloader))
        print("Epoch:  {}/{}.. ".format(e+1, epochs),
              "Train Loss: {:.3f}.. ".format(running_loss/len(train_dataloader)),
              "Test Loss: {:.3f}.. ".format(test_loss/len(valid_dataloader)),
              "Test Accuracy: {:.3f}".format(accuracy/len(valid_dataloader)))
# Out:
# Test Loss: 1.187..  Test Accuracy: 0.713
# 'for e in range(epochs):\n    running_loss = 0\n    for images, labels in train_dataloader:\n        steps += 1\n        # Move input and label tensors to the default device\n        images, labels = images.to(device), labels.to(device)\n        optimizer.zero_grad()\n        logps = model.forward(images)\n        loss = criterion(logps, labels)\n        loss.backward()\n        optimizer.step()\n        running_loss += loss.item()\n        print("Epoch: ", epoch, "     Loss: ", loss)\n        \n    else:\n        ## TODO: Implement the validation pass and print out the validation accuracy\n        '

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_data.class_to_idx
checkpoint = {'input_size': 25088,
              'output_size': 102,
              'epochs': 2,
              'state_dict': model.state_dict(),
              'optimizer': optimizer.state_dict()}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    classifier = nn.Sequential(nn.Linear(25088, 2048),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(2048, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(512, 102),
                                 nn.LogSoftmax(dim=1))
    model = models.vgg11(pretrained=True)
    model.classifier = classifier
    model.load_state_dict(checkpoint['state_dict'])
    return model
model = load_checkpoint('checkpoint.pth')
print(model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-f5b484f03e91> in <module>()
#       5     model.load_state_dict(checkpoint['state_dict'])
#       6     return model
# ----> 7 model = load_checkpoint('checkpoint.pth')
#       8 print(model)
#
# <ipython-input-18-f5b484f03e91> in load_checkpoint(filepath)
#       3     checkpoint = torch.load(filepath)
#       4     model = models.vgg11(pretrained=True)
# ----> 5     model.load_state_dict(checkpoint['state_dict'])
#       6     return model
#       7 model = load_checkpoint('checkpoint.pth')
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     719         if len(error_msgs) > 0:
#     720             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 721                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     722
#     723     def parameters(self):
#
# RuntimeError: Error(s) in loading state_dict for VGG:
# 	While copying the parameter named "classifier.0.weight", whose dimensions in the model are torch.Size([4096, 25088]) and whose dimensions in the checkpoint are torch.Size([2048, 25088]).
# 	While copying the parameter named "classifier.0.bias", whose dimensions in the model are torch.Size([4096]) and whose dimensions in the checkpoint are torch.Size([2048]).
# 	While copying the parameter named "classifier.3.weight", whose dimensions in the model are torch.Size([4096, 4096]) and whose dimensions in the checkpoint are torch.Size([512, 2048]).
# 	While copying the parameter named "classifier.3.bias", whose dimensions in the model are torch.Size([4096]) and whose dimensions in the checkpoint are torch.Size([512]).
# 	While copying the parameter named "classifier.6.weight", whose dimensions in the model are torch.Size([1000, 4096]) and whose dimensions in the checkpoint are torch.Size([102, 512]).
# 	While copying the parameter named "classifier.6.bias", whose dimensions in the model are torch.Size([1000]) and whose dimensions in the checkpoint are torch.Size([102]).

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
    e1 = image.shape()[0]
    e2 = image.shape()[1]
    if e1 < e2:
        h = int(256/e1 * e2)
        image.resize(256, h)
        m = int((h-224)/2)
        image.crop(16,m,16+224,m+224)
    else:
        w = (int(256/e2 * e1)
        image = image.resize(w, 256))
        m = int((w-224)/2)
        image.crop(m,16,m+224,16+224)
    np_image = np.array(image)
    np_image /= 255
    np_image -= [0.485, 0.456, 0.406]
    np_image /= [0.229, 0.224, 0.225]
    np_image.transpose((2,0,1))
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    img = Image.open(image_path)
    img = process_image(img)
    img.from_numpy()
    log_ps = model(img)
    ps = torch.exp(log_ps)
    probs, classes = ps.topk(topk, dim=1)
    return (probs, classes)
    # TODO: Implement the code to predict the class from an image file

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
